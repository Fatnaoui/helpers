# %%
# Check which env you are working with 
import sys
print(sys.executable)
# Out:
# /home/fatnaoui/tools/miniforge3/envs/fasttext/bin/python

# %%
import json
import os

labels = ["en", "it", "fr", "es", "ar_ma", "ar_msa", "ar_ma_latin", "other_ar", "other_lg"]
splits = ["train", "validation", "test"]

for split in splits:
    all_split_lines = []

    for label in labels:
        in_path = f"{label}/{split}.jsonl"
        if not os.path.exists(in_path):
            # some languages may not have all splits
            continue

        with open(in_path, "r", encoding="utf-8") as f:
            for line in f:
                line = line.strip()
                if not line:
                    continue

                obj = json.loads(line)
                text = obj.get("text")
                if not text:
                    continue

                text = " ".join(text.split())
                all_split_lines.append(f"__label__{label} {text}\n")

        # OPTIONAL: delete jsonl after processing
        # os.remove(in_path)

    out_path = f"{split}.txt"
    with open(out_path, "w", encoding="utf-8") as f:
        f.writelines(all_split_lines)

    print(f"{split}: wrote {len(all_split_lines)} lines to {out_path}")

print("Done: train.txt, validation.txt, test.txt created.")
# Out:
# Done preparing en data
#
# Done preparing it data
#
# Done preparing fr data
#
# Done preparing es data
#
# Done preparing ar_ma data
#
# Done preparing ar_msa data
#
# Done preparing ar_ma_latin data
#
# Done preparing other_ar data
#
# Done preparing other_lg data

# %%
# don't worry if the editer shows them incorrectly, it is the way how it reads. To verify
path = "ar_ma/train.jsonl"   # change this to your real path

with open(path, "r", encoding="utf-8") as f:
    for i in range(5):  # show first 5 lines
        line = f.readline()
        if not line:
            break
        print(repr(line))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[9], line 4
#       1 # don't worry if the editer shows them incorrectly, it is the way how it reads. To verify
#       2 path = "ar_ma/train.txt"   # change this to your real path
# ----> 4 with open(path, "r", encoding="utf-8") as f:
#       5     for i in range(5):  # show first 5 lines
#       6         line = f.readline()
#
# File ~/tools/miniforge3/envs/fasttext/lib/python3.10/site-packages/IPython/core/interactiveshell.py:324, in _modified_open(file, *args, **kwargs)
#     317 if file in {0, 1, 2}:
#     318     raise ValueError(
#     319         f"IPython won't let you open fd={file} by default "
#     320         "as it is likely to crash IPython. If you know what you are doing, "
#     321         "you can use builtins' open."
#     322     )
# --> 324 return io_open(file, *args, **kwargs)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'ar_ma/train.txt'
